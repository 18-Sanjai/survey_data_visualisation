# %%
import pandas as pd

df = pd.read_csv("C:\\Users\\SANJAIKRISHNAN\\Downloads\\Starbucks satisfactory survey encode cleaned.csv")

# %%
display(df.head())
display(df.columns)
df.info()
# Out:
#    Id  gender  age  status  income  visitNo  method  timeSpend  location  \
# 0   1       1    1       0       0        3       0          1         0
# 1   2       1    1       0       0        3       2          0         1
# 2   3       0    1       2       0        2       0          1         2
# 3   4       1    1       0       0        3       2          0         2
# 4   5       0    1       0       0        2       2          1         1
#
#    membershipCard  ...  chooseRate  promoMethodApp  promoMethodSoc  \
# 0               0  ...           3               1               1
# 1               0  ...           2               1               1
# 2               0  ...           3               1               1
# 3               1  ...           3               1               1
# 4               1  ...           3               1               1
#
#    promoMethodEmail  promoMethodDeal  promoMethodFriend  promoMethodDisplay  \
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

for column in df.columns:
    if column in ['Id', 'loyal']: 
        continue
    if df[column].nunique() < 10 or df[column].dtype == 'object':
        plt.figure(figsize=(8, 6))
        sns.countplot(x=column, data=df)
        plt.title(f'Distribution of {column}')
        plt.xlabel(column)
        plt.ylabel('Count')
        plt.show()
        plt.close()
    elif df[column].nunique() <= 5: 
        plt.figure(figsize=(8, 8))
        df[column].value_counts().plot.pie(autopct='%1.1f%%', startangle=90)
        plt.title(f'Proportion of {column}')
        plt.ylabel('') # Hide the default y-label
        plt.show()
        plt.close()


plt.figure(figsize=(12, 10))
correlation_matrix = df.drop(columns=['Id']).corr()
sns.heatmap(correlation_matrix, annot=False, cmap='coolwarm')
plt.title('Correlation Matrix of Survey Responses')
plt.show()
plt.close()
